# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('bank.csv')
dataset
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
a=dataset.drop(['contact','day','month','duration','campaign','pdays','previous','poutcome','default'],axis=1)
a
# Out:
#        age          job  marital  education  balance housing loan deposit
# 0       59       admin.  married  secondary     2343     yes   no     yes
# 1       56       admin.  married  secondary       45      no   no     yes
# 2       41   technician  married  secondary     1270     yes   no     yes
# 3       55     services  married  secondary     2476     yes   no     yes
# 4       54       admin.  married   tertiary      184      no   no     yes
# ...    ...          ...      ...        ...      ...     ...  ...     ...
# 11157   33  blue-collar   single    primary        1     yes   no      no
# 11158   39     services  married  secondary      733      no   no      no
# 11159   32   technician   single  secondary       29      no   no      no
# 11160   43   technician  married  secondary        0      no  yes      no
# 11161   34   technician  married  secondary        0      no   no      no
#
# [11162 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
dataset['deposit']=lb.fit_transform(dataset['deposit'])
dataset['housing']=lb.fit_transform(dataset['housing'])
dataset['loan']=lb.fit_transform(dataset['loan'])
dataset['marital']=lb.fit_transform(dataset['marital'])
dataset['job']=lb.fit_transform(dataset['job'])
dataset['education']=lb.fit_transform(dataset['education'])

# %%
a=dataset.drop(['contact','day','month','duration','campaign','pdays','previous','poutcome','default'],axis=1)
a
# Out:
#        age  job  marital  education  balance  housing  loan  deposit
# 0       59    0        1          1     2343        1     0        1
# 1       56    0        1          1       45        0     0        1
# 2       41    9        1          1     1270        1     0        1
# 3       55    7        1          1     2476        1     0        1
# 4       54    0        1          2      184        0     0        1
# ...    ...  ...      ...        ...      ...      ...   ...      ...
# 11157   33    1        2          0        1        1     0        0
# 11158   39    7        1          1      733        0     0        0
# 11159   32    9        2          1       29        0     0        0
# 11160   43    9        1          1        0        0     1        0
# 11161   34    9        1          1        0        0     0        0
#
# [11162 rows x 8 columns]

# %%
x=a.iloc[:,:7].values
x
# Out:
# array([[  59,    0,    1, ..., 2343,    1,    0],
#        [  56,    0,    1, ...,   45,    0,    0],
#        [  41,    9,    1, ..., 1270,    1,    0],
#        ...,
#        [  32,    9,    2, ...,   29,    0,    0],
#        [  43,    9,    1, ...,    0,    0,    1],
#        [  34,    9,    1, ...,    0,    0,    0]], dtype=int64)

# %%
dataset['housing']=lb.fit_transform(dataset['housing'])

# %%
y=a.iloc[:,7:8].values
y
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
mr=LinearRegression()

# %%
mr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from joblib import dump
dump(lb,"project1.save")
# Out:
# ['project1.save']

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor ( random_state=0)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
y_pred=dt.predict(x_test)
y_pred
# Out:
# array([1., 0., 0., ..., 0., 0., 0.])

# %%
import pickle
pickle.dump(dt,open('project1.pkl','wb'))

# %%
dt.predict([[1,1,1,1,1,1,1,
            
            ]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-58a7dd2fa6b7> in <module>
# ----> 1 dt.predict([[1,1,1,1,1,1,1,1]])
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     417         """
#     418         check_is_fitted(self)
# --> 419         X = self._validate_X_predict(X, check_input)
#     420         proba = self.tree_.predict(X)
#     421         n_samples = X.shape[0]
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
#     389                              "match the input. Model n_features is %s and "
#     390                              "input n_features is %s "
# --> 391                              % (self.n_features_, n_features))
#     392
#     393         return X
#
# ...
